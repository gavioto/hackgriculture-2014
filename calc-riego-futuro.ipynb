# %% [markdown]
# Hemos instalado Anaconda e importamos los datos
#
# Importamos datos de AEmet metereológicos (SIAR)
#
# Datos que no necesitamos:
#     - velocidad del viento
#     - dirección del viento
#     - velocidad del viento Ma
#     - hora del viento
#
#     - id provincia
#     - id estacion
#
# Queremos calcular la Kc real que utiliza el agrucultor a partir de
#     - evapotranspiración
#     - consumos reles

# %%
# Import libraries
import pandas as pd
# import matplotlib.pyplot as plt
import numpy.random as np
import sys

#import AEMET
humedad_temperatura = pd.read_csv("Datos proyecto Riego Nava de arevalo.csv", sep=";", decimal = ',')

df_fecha_et=humedad_temperatura[['Fecha','EtPMon']]

#humedad_temperatura.dtypes
df_fecha_et.dtypes
# Out:
# Fecha      object
# EtPMon    float64
# dtype: object

# %%
humedad_temperatura['Fecha'] = pd.to_datetime(humedad_temperatura['Fecha'])
humedad_temperatura.head()
# Out:
#    IdProvincia  IdEstacion      Fecha  Year  Dia t_media_grados t_max_grados  \
# 0            5           1 2010-01-01  2010    1            3,1         6,69
# 1            5           1 2010-02-01  2010    2            3,8         7,42
# 2            5           1 2010-03-01  2010    3              6         8,96
# 3            5           1 2010-04-01  2010    4           5,89          8,5
# 4            5           1 2010-05-01  2010    5            4,3         5,29
#
#   hora_temp_max t_min_grados hora_temp_min      ...      hora_hum_min  \
# 0         13:20         0,96         02:10      ...             09:40
# 1         13:40         0,15         02:00      ...             10:30
# 2         15:00         3,29         01:20      ...               NaN
# 3         10:00         3,89         19:20      ...             10:20
# 4         14:00         2,76         00:00      ...             16:20
#
#   vel_viento_m_s dir_viento_grad VelVientoMa_m_s hora_vel_max  \
# 0           5,97           253,6           14,38        10:38
# 1           2,69           209,2            7,69        20:13
# 2           2,83           173,9            7,95        05:50
# 3           1,78           119,3            7,71        10:16
# 4           2,02           350,1            4,83        22:14
#
#   dir_viento_vel_max_grad radiacion_MJ_m2) precipitacion_mm PePMon EtPMon
# 0                   251,4             5,63              0,6      0   0,78
# 1                   169,2             4,68                0      0   0,65
# 2                   173,8             1,46                4   1,03   0,62
# 3                   184,9             1,65              8,2    4,3   0,53
# 4                   318,2             2,11              1,4      0   0,48
#
# [5 rows x 24 columns]

# %%
temperatura_head.replace()

# %%
list(humedad_temperatura.columns.values)

df_fecha_et['Fecha'] = pd.to_datetime(df_fecha_et['Fecha'])

# %%
#df.resample("1D", fill_method="ffill")
#pd.rolling_mean(df['EtPMon'], window=3, min_periods=1)

df_fecha_et['EtPMon_mavg'] = pd.rolling_mean(df_fecha_et['EtPMon'], 3, min_periods=3)
df_fecha_et['EtPMon_mavg'] = pd.rolling_mean(df_fecha_et['EtPMon'], 3, min_periods=3)

df_fecha_et
# Out:
# -c:4: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row